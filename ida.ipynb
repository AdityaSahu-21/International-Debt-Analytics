# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
data = pd.read_csv("WB_IDS_WIDEF (1).csv")

# %%
data.isnull().sum().reset_index()
# Out:
#              index       0
# 0             FREQ       0
# 1       FREQ_LABEL       0
# 2         REF_AREA       0
# 3   REF_AREA_LABEL       0
# 4        INDICATOR       0
# ..             ...     ...
# 79            2027  355622
# 80            2028  356089
# 81            2029  356716
# 82            2030  357077
# 83            2031  357543
#
# [84 rows x 2 columns]

# %%
con = create_engine("mysql+pymysql://root:aditya@localhost:3306/Deb_data")

# %%
data.columns
# Out:
# Index(['FREQ', 'FREQ_LABEL', 'REF_AREA', 'REF_AREA_LABEL', 'INDICATOR',
#        'INDICATOR_LABEL', 'UNIT_MEASURE', 'UNIT_MEASURE_LABEL',
#        'COMP_BREAKDOWN_1', 'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2',
#        'COMP_BREAKDOWN_2_LABEL', 'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL',
#        'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT', 'UNIT_MULT_LABEL',
#        'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF', 'OBS_CONF_LABEL', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024',
# ...

# %%
data.head(10)
# Out:
#   FREQ FREQ_LABEL REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0    A     Annual      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1    A     Annual      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2    A     Annual      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3    A     Annual      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4    A     Annual      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
# 5    A     Annual      AFG    Afghanistan       WB_IDS_BX_PEF_CD_DT
# 6    A     Annual      AFG    Afghanistan  WB_IDS_BX_TRF_PWKR_CD_DT
# 7    A     Annual      AFG    Afghanistan        WB_IDS_DT_AMT_DIMF
# 8    A     Annual      AFG    Afghanistan        WB_IDS_DT_AMT_DIMF
# 9    A     Annual      AFG    Afghanistan        WB_IDS_DT_AMT_DLTF
#
#                                      INDICATOR_LABEL UNIT_MEASURE  \
# 0                            Current account balance          USD
# 1            Grants, excluding technical cooperation          USD
# ...

# %%
data.DATABASE_ID.nunique()
# Out:
# 1

# %%
data.COMP_BREAKDOWN_1_LABEL.nunique()
# Out:
# 303

# %%
non_unique = []
for column in data.columns:
    print(column, data[column].nunique())
    if data [column].nunique()<2:
        non_unique.append(column)
# Out:
# FREQ 1
# FREQ_LABEL 1
# REF_AREA 134
# REF_AREA_LABEL 134
# INDICATOR 102
# INDICATOR_LABEL 102
# UNIT_MEASURE 7
# UNIT_MEASURE_LABEL 7
# COMP_BREAKDOWN_1 303
# COMP_BREAKDOWN_1_LABEL 303
# COMP_BREAKDOWN_2 6
# COMP_BREAKDOWN_2_LABEL 6
# COMP_BREAKDOWN_3 5
# COMP_BREAKDOWN_3_LABEL 5
# DATABASE_ID 1
# DATABASE_ID_LABEL 1
# UNIT_MULT 1
# UNIT_MULT_LABEL 1
# OBS_STATUS 1
# OBS_STATUS_LABEL 1
# OBS_CONF 1
# OBS_CONF_LABEL 1
# 1970 13986
# 1971 15015
# 1972 16029
# 1973 17335
# 1974 18642
# 1975 19892
# 1976 21609
# 1977 23327
# 1978 24835
# 1979 26063
# 1980 27670
# 1981 29281
# 1982 30728
# 1983 31922
# 1984 32576
# 1985 33137
# 1986 33625
# 1987 33865
# 1988 34205
# 1989 42817
# 1990 42875
# 1991 42687
# 1992 42754
# 1993 42585
# 1994 43052
# 1995 42754
# 1996 42369
# 1997 41829
# 1998 41185
# 1999 40995
# 2000 40969
# 2001 41025
# 2002 40074
# 2003 39166
# 2004 38621
# 2005 37635
# 2006 36835
# 2007 35611
# 2008 35436
# 2009 34921
# 2010 34892
# 2011 33837
# 2012 33317
# 2013 33522
# ...

# %%
data.drop(columns= non_unique, inplace=True)

# %%
data.columns
# Out:
# Index(['REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026',
#        '2027', '2028', '2029', '2030', '2031'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366193 entries, 0 to 366192
# Data columns (total 74 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   REF_AREA                366193 non-null  str
#  1   REF_AREA_LABEL          366193 non-null  str
#  2   INDICATOR               366193 non-null  str
#  3   INDICATOR_LABEL         366193 non-null  str
#  4   UNIT_MEASURE            366193 non-null  str
#  5   UNIT_MEASURE_LABEL      366193 non-null  str
#  6   COMP_BREAKDOWN_1        366193 non-null  str
#  7   COMP_BREAKDOWN_1_LABEL  366193 non-null  str
#  8   COMP_BREAKDOWN_2        366193 non-null  str
#  9   COMP_BREAKDOWN_2_LABEL  366193 non-null  str
#  10  COMP_BREAKDOWN_3        366193 non-null  str
#  11  COMP_BREAKDOWN_3_LABEL  366193 non-null  str
#  12  1970                    171121 non-null  float64
#  13  1971                    175127 non-null  float64
# ...

# %%
uniques = {}
for column in data.columns:
    if data[column].dtype == 'str':
        uniques[column] = data[column].unique()
    else:
        continue

# %%
uniques = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in uniques.items()]))
uniques.to_csv('uniques_IDA.csv')

# %%
column = data.columns
id_vars= column[:12]
value_vars = column[12:]

print(id_vars)
print(value_vars)
# Out:
# Index(['REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL'],
#       dtype='str')
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031'],
#       dtype='str')

# %%
df_long = pd.melt(data,
    id_vars= id_vars,
    value_vars= value_vars,
    var_name='Year',
    value_name='Value'

)
print (df_long)
# Out:
#          REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0             AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1             AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2             AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3             AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4             AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
# ...           ...            ...                       ...
# 22703961      ZWE       Zimbabwe             WB_IDS_FI_RES
# 22703962      ZWE       Zimbabwe          WB_IDS_FI_RES_DT
# 22703963      ZWE       Zimbabwe          WB_IDS_FI_RES_MO
# 22703964      ZWE       Zimbabwe     WB_IDS_NY_GNP_MKTP_CD
# 22703965      ZWE       Zimbabwe        WB_IDS_SP_POP_TOTL
#
#                                             INDICATOR_LABEL UNIT_MEASURE  \
# 0                                   Current account balance          USD
# 1                   Grants, excluding technical cooperation          USD
# ...

# %%
df_long.head()
# Out:
#   REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                      INDICATOR_LABEL UNIT_MEASURE  \
# 0                            Current account balance          USD
# 1            Grants, excluding technical cooperation          USD
# 2                       Technical cooperation grants          USD
# 3  Foreign direct investment, net inflows in repo...          USD
# 4                              Primary income on FDI          USD
#
#   UNIT_MEASURE_LABEL             COMP_BREAKDOWN_1   COMP_BREAKDOWN_1_LABEL  \
# 0         US dollars  WB_IDS_COUNTERPART_AREA_WLD  Counterpart Area: World
# 1         US dollars  WB_IDS_COUNTERPART_AREA_WLD  Counterpart Area: World
# ...

# %%
df_long.shape
# Out:
# (22703966, 14)

# %%
data.columns
# Out:
# Index(['REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026',
#        '2027', '2028', '2029', '2030', '2031'],
#       dtype='str')

# %%
uniques = {}
for col in data.columns:
       uniques[col] = data[col].unique()

# %%
uniques
# Out:
# {'REF_AREA': <StringArray>
#  ['AFG', 'AGO', 'ALB', 'ARG', 'ARM', 'AZE', 'BDI', 'BEN', 'BFA', 'BGD',
#   ...
#   'UZB', 'VCT', 'VNM', 'VUT', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE']
#  Length: 134, dtype: str,
#  'REF_AREA_LABEL': <StringArray>
#  [                   'Afghanistan',                         'Angola',
#                          'Albania',                      'Argentina',
#                          'Armenia',                     'Azerbaijan',
#                          'Burundi',                          'Benin',
#                     'Burkina Faso',                     'Bangladesh',
#   ...
#                       'Uzbekistan', 'St. Vincent and the Grenadines',
#                         'Viet Nam',                        'Vanuatu',
#                            'Samoa',                         'Kosovo',
#                      'Yemen, Rep.',                   'South Africa',
#                           'Zambia',                       'Zimbabwe']
# ...

# %%
uniques = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in uniques.items()]))

# %%
df_long.rename(columns ={"COMP_BREAKDOWN_1_LABEL" : "Counter_Part" , "COMP_BREAKDOWN_2_LABEL" : "Nature" , "COMP_BREAKDOWN_3_LABEL" : "Type"}, inplace =True)

# %%
data.columns = data.columns.str.strip()

# %%
df_long['COMP_BREAKDOWN_1_LABEL']  = data['COMP_BREAKDOWN_1_LABEL'].str.replace("Counterpart Area: ", "" )

# %%
df_long.drop(columns=['INDICATOR' , 'UNIT_MEASURE' , 'COMP_BREAKDOWN_1' , 'COMP_BREAKDOWN_2' , 'COMP_BREAKDOWN_3'], errors='ignore', inplace = True)

# %%
df_long.head(5)
# Out:
#   REF_AREA REF_AREA_LABEL                                    INDICATOR_LABEL  \
# 0      AFG    Afghanistan                            Current account balance
# 1      AFG    Afghanistan            Grants, excluding technical cooperation
# 2      AFG    Afghanistan                       Technical cooperation grants
# 3      AFG    Afghanistan  Foreign direct investment, net inflows in repo...
# 4      AFG    Afghanistan                              Primary income on FDI
#
#   UNIT_MEASURE_LABEL             Counter_Part          Nature            Type  \
# 0         US dollars  Counterpart Area: World  Not Applicable  Not Applicable
# 1         US dollars  Counterpart Area: World  Not Applicable  Not Applicable
# 2         US dollars  Counterpart Area: World  Not Applicable  Not Applicable
# 3         US dollars  Counterpart Area: World  Not Applicable  Not Applicable
# 4         US dollars  Counterpart Area: World  Not Applicable  Not Applicable
#
# ...

# %%
#df_long.to_csv("data.csv")

# %%
#from sqlalchemy import create_engine
#engine = create_engine("mysql+pymysql://root:9648@localhost/debt_data")

# %%
#df_long.to_sql(
#    name = "ida2",
#    con=engine,
#    index=False,
#    if_exists='replace',
#    chunksize=10000,
#    method='multi'
#)

# %%
df2_melt = pd.melt(
    data,
    id_vars=id_vars,
    value_vars= value_vars,
    var_name='Year',
    value_name='value'
    )

# %%
india_df = df2_melt[df2_melt['REF_AREA_LABEL'] == 'India']
india_df
# Out:
#          REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 138806        IND          India     WB_IDS_BN_CAB_XOKA_CD
# 138807        IND          India  WB_IDS_BX_GRT_EXTA_CD_DT
# 138808        IND          India  WB_IDS_BX_GRT_TECH_CD_DT
# 138809        IND          India  WB_IDS_BX_KLT_DINV_CD_DT
# 138810        IND          India  WB_IDS_BX_KLT_DREM_CD_DT
# ...           ...            ...                       ...
# 22480025      IND          India             WB_IDS_FI_RES
# 22480026      IND          India          WB_IDS_FI_RES_DT
# 22480027      IND          India          WB_IDS_FI_RES_MO
# 22480028      IND          India     WB_IDS_NY_GNP_MKTP_CD
# 22480029      IND          India        WB_IDS_SP_POP_TOTL
#
#                                             INDICATOR_LABEL UNIT_MEASURE  \
# 138806                              Current account balance          USD
# 138807              Grants, excluding technical cooperation          USD
# ...

# %%
#df2_melt['COMP_BREAKDOWN_1_LABEL'] = df2_melt['COMP_BREAKDOWN_1_LABEL'].str.replace('Counterpart Area: ','')

# %%
india_df.head(5)
# Out:
#        REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 138806      IND          India     WB_IDS_BN_CAB_XOKA_CD
# 138807      IND          India  WB_IDS_BX_GRT_EXTA_CD_DT
# 138808      IND          India  WB_IDS_BX_GRT_TECH_CD_DT
# 138809      IND          India  WB_IDS_BX_KLT_DINV_CD_DT
# 138810      IND          India  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                           INDICATOR_LABEL UNIT_MEASURE  \
# 138806                            Current account balance          USD
# 138807            Grants, excluding technical cooperation          USD
# 138808                       Technical cooperation grants          USD
# 138809  Foreign direct investment, net inflows in repo...          USD
# 138810                              Primary income on FDI          USD
#
#        UNIT_MEASURE_LABEL             COMP_BREAKDOWN_1  \
# 138806         US dollars  WB_IDS_COUNTERPART_AREA_WLD
# 138807         US dollars  WB_IDS_COUNTERPART_AREA_WLD
# ...

# %%
#india_df.columns

# %%
#india_df.shape
# Out:
# (213962, 14)

# %%
data['Counterpart'] = data['COMP_BREAKDOWN_1_LABEL'].str.replace('Counterpart Area: ','', regex = False)

# %%
data.Counterpart.unique()
# Out:
# <StringArray>
# [                                      'World',
#                  'International Monetary Fund',
#                              'Asian Dev. Bank',
#                                     'Bulgaria',
#                       'Other Multiple Lenders',
#                        'Germany, Fed. Rep. of',
#                               'World Bank-IDA',
#                                         'Iraq',
#                            'Islamic Dev. Bank',
#             'OPEC Fund for International Dev.',
#  ...
#  'UN-World Intellectual Property Organization',
#         'UN-World Meteorological Organization',
#                                        'Samoa',
#                     'World Trade Organization',
#                                       'Kosovo',
#                           'Yemen, Republic Of',
#                                   'Yugoslavia',
#                                 'South Africa',
#                                       'Zambia',
# ...

# %% [markdown]
# sortred Indicator

# %%
data['Counterpart'].value_counts().head(50)
# Out:
# Counterpart
# World                                            12401
# France                                            6281
# Germany, Fed. Rep. of                             6113
# United States                                     5987
# United Kingdom                                    5775
# Japan                                             5366
# Multiple Lenders                                  5293
# Italy                                             5124
# China                                             5002
# Bondholders                                       4766
# World Bank-IDA                                    4723
# Belgium                                           4675
# Netherlands                                       4514
# Switzerland                                       4502
# Austria                                           4496
# Spain                                             4391
# International Fund for Agricultural Dev.          4309
# ...

# %%
#data.columns

# %%
data['INDICATOR_LABEL'].to_csv('indicator.csv', index=False)

# %%
india_df = data.loc[data['REF_AREA_LABEL'] == "India"]

# %%
india_df.head()
# Out:
#        REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 138806      IND          India     WB_IDS_BN_CAB_XOKA_CD
# 138807      IND          India  WB_IDS_BX_GRT_EXTA_CD_DT
# 138808      IND          India  WB_IDS_BX_GRT_TECH_CD_DT
# 138809      IND          India  WB_IDS_BX_KLT_DINV_CD_DT
# 138810      IND          India  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                           INDICATOR_LABEL UNIT_MEASURE  \
# 138806                            Current account balance          USD
# 138807            Grants, excluding technical cooperation          USD
# 138808                       Technical cooperation grants          USD
# 138809  Foreign direct investment, net inflows in repo...          USD
# 138810                              Primary income on FDI          USD
#
#        UNIT_MEASURE_LABEL             COMP_BREAKDOWN_1  \
# 138806         US dollars  WB_IDS_COUNTERPART_AREA_WLD
# 138807         US dollars  WB_IDS_COUNTERPART_AREA_WLD
# ...

# %%
data.drop(columns=['UNIT_MEASURE',], errors='ignore', inplace=True)

# %%
data.head(5)
# Out:
#   REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                      INDICATOR_LABEL UNIT_MEASURE_LABEL  \
# 0                            Current account balance         US dollars
# 1            Grants, excluding technical cooperation         US dollars
# 2                       Technical cooperation grants         US dollars
# 3  Foreign direct investment, net inflows in repo...         US dollars
# 4                              Primary income on FDI         US dollars
#
#               COMP_BREAKDOWN_1   COMP_BREAKDOWN_1_LABEL COMP_BREAKDOWN_2  \
# 0  WB_IDS_COUNTERPART_AREA_WLD  Counterpart Area: World               _Z
# ...

# %%
data.drop(columns=['COMP_BREAKDOWN_1',], errors='ignore', inplace=True)

# %%
data.head(5)
# Out:
#   REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                      INDICATOR_LABEL UNIT_MEASURE_LABEL  \
# 0                            Current account balance         US dollars
# 1            Grants, excluding technical cooperation         US dollars
# 2                       Technical cooperation grants         US dollars
# 3  Foreign direct investment, net inflows in repo...         US dollars
# 4                              Primary income on FDI         US dollars
#
#     COMP_BREAKDOWN_1_LABEL COMP_BREAKDOWN_2 COMP_BREAKDOWN_2_LABEL  \
# 0  Counterpart Area: World               _Z         Not Applicable
# 1  Counterpart Area: World               _Z         Not Applicable
# ...

# %%
data.drop(columns=['COMP_BREAKDOWN_3',], errors='ignore', inplace=True)

# %%
data.head(5)
# Out:
#   REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                      INDICATOR_LABEL UNIT_MEASURE_LABEL  \
# 0                            Current account balance         US dollars
# 1            Grants, excluding technical cooperation         US dollars
# 2                       Technical cooperation grants         US dollars
# 3  Foreign direct investment, net inflows in repo...         US dollars
# 4                              Primary income on FDI         US dollars
#
#     COMP_BREAKDOWN_1_LABEL COMP_BREAKDOWN_2 COMP_BREAKDOWN_2_LABEL  \
# 0  Counterpart Area: World               _Z         Not Applicable
# 1  Counterpart Area: World               _Z         Not Applicable
# ...

# %%
data.drop(columns=['COMP_BREAKDOWN_2',], errors='ignore',inplace=True)

# %%
data["COMP_BREAKDOWN_1_LABEL"] = data['COMP_BREAKDOWN_1_LABEL'].str.replace("Counterpart Area: " , "")

# %%
data.columns
# Out:
# Index(['REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL',
#        'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1_LABEL',
#        'COMP_BREAKDOWN_2_LABEL', 'COMP_BREAKDOWN_3_LABEL', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025',
#        '2026', '2027', '2028', '2029', '2030', '2031', 'Counterpart'],
#       dtype='str')

# %%
india_df.rename(columns={"COMP_BREAKDOWN_1_LABEL":"Counter_Part"}, inplace=True)

# %%
india_df.drop(columns=['COMP_BREAKDOWN_1',],errors='ignore',inplace=True)

# %%
india_df.drop(columns=['UNIT_MEASURE',],errors='ignore',inplace=True)

# %%
india_df.drop(columns=['COMP_BREAKDOWN_2',],errors='ignore',inplace=True)

# %%
india_df.drop(columns=['COMP_BREAKDOWN_3',],errors='ignore',inplace=True)

# %%
india_df.rename(columns={"COMP_BREAKDOWN_2_LABEL":"Nature" },inplace=True)

# %%
india_df.rename(columns={"COMP_BREAKDOWN_3_LABEL":"Type"},inplace=True)

# %%
india_df.head(5)
# Out:
#        REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 138806      IND          India     WB_IDS_BN_CAB_XOKA_CD
# 138807      IND          India  WB_IDS_BX_GRT_EXTA_CD_DT
# 138808      IND          India  WB_IDS_BX_GRT_TECH_CD_DT
# 138809      IND          India  WB_IDS_BX_KLT_DINV_CD_DT
# 138810      IND          India  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                           INDICATOR_LABEL UNIT_MEASURE_LABEL  \
# 138806                            Current account balance         US dollars
# 138807            Grants, excluding technical cooperation         US dollars
# 138808                       Technical cooperation grants         US dollars
# 138809  Foreign direct investment, net inflows in repo...         US dollars
# 138810                              Primary income on FDI         US dollars
#
#                    Counter_Part          Nature            Type         1970  \
# 138806  Counterpart Area: World  Not Applicable  Not Applicable          NaN
# ...

# %%
india_df.to_csv("India_unique_data.csv")

# %%
data.rename(columns={"COMP_BREAKDOWN_1_LABEL":"Counter_Part"},inplace=True)

# %%
data.rename(columns ={"COMP_BREAKDOWN_2_LABEL" : "Nature"}, inplace =True)

# %%
data.rename(columns ={ "COMP_BREAKDOWN_3_LABEL": "Type"}, inplace =True)

# %%
data.head()
# Out:
#   REF_AREA REF_AREA_LABEL                 INDICATOR  \
# 0      AFG    Afghanistan     WB_IDS_BN_CAB_XOKA_CD
# 1      AFG    Afghanistan  WB_IDS_BX_GRT_EXTA_CD_DT
# 2      AFG    Afghanistan  WB_IDS_BX_GRT_TECH_CD_DT
# 3      AFG    Afghanistan  WB_IDS_BX_KLT_DINV_CD_DT
# 4      AFG    Afghanistan  WB_IDS_BX_KLT_DREM_CD_DT
#
#                                      INDICATOR_LABEL UNIT_MEASURE_LABEL  \
# 0                            Current account balance         US dollars
# 1            Grants, excluding technical cooperation         US dollars
# 2                       Technical cooperation grants         US dollars
# 3  Foreign direct investment, net inflows in repo...         US dollars
# 4                              Primary income on FDI         US dollars
#
#   Counter_Part          Nature            Type  1970  1971  ...  2023  2024  \
# 0        World  Not Applicable  Not Applicable   NaN   NaN  ...   NaN   NaN
# ...

# %%
import pandas as pd

df = pd.read_csv("India_unique_data.csv")
print(df.shape)
# Out:
# (3451, 72)

# %%
#from sqlalchemy import create_engine

#engine= create_engine("mysql+pymysql://root:9648@localhost/debt_data")

# %%
#engine= create_engine("mysql+pymysql://root:9648@localhost/debt_data")

# %%
#con = create_engine("mysql+pymysql://root:aditya@localhost:3306/Debt_data")

# %%
'''df.to_sql(
    name="india_data",
    con=engine,
    index=False,
    if_exists='replace',
    chunksize=10000
)'''
# Out:
# 'df.to_sql(\n    name="india_data",\n    con=engine,\n    index=False,\n    if_exists=\'replace\',\n    chunksize=10000\n)'

# %%
india_df.to_csv("IND.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 india_df.to_csv("IND.csv")
#
# NameError: name 'india_df' is not defined
